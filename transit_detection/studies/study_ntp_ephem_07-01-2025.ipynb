# %%
# 3rd party
import tensorflow as tf
import lightkurve as lk
import pandas as pd
import numpy as np
from pathlib import Path

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib.colors import LogNorm

from scipy.interpolate import interp1d
from collections import defaultdict
import json

# %%
tce_tbl_fp = Path(
    "/Users/jochoa4/Projects/exoplanet_transit_classification/ephemeris_tables/preprocessing_tce_tables/tess_2min_tces_dv_s1-s68_all_msectors_11-29-2023_2157_newlabels_nebs_npcs_bds_ebsntps_to_unks.csv"
)

tce_tbl = pd.read_csv(tce_tbl_fp)
tce_tbl = tce_tbl.loc[
        tce_tbl["label"].isin(["EB", "KP", "CP", "NTP", "NEB", "NPC"])
]
tce_tbl = tce_tbl.rename(columns={"uid": "tce_uid", "label": "disposition", "uid": "tce_uid"})
# Out:
# /var/folders/_z/srkh35f94rd_6jrkc3kv29hm0000gp/T/ipykernel_14520/4188963064.py:5: DtypeWarning: Columns (364,366,367,370,371) have mixed types. Specify dtype option on import or set low_memory=False.
#   tce_tbl = pd.read_csv(tce_tbl_fp)

# %%
unfil_tce_tbl = pd.read_csv(tce_tbl_fp)
unfil_tce_tbl = unfil_tce_tbl.rename(columns={"uid": "tce_uid", "label": "disposition", "uid": "tce_uid"})
# Out:
# /var/folders/_z/srkh35f94rd_6jrkc3kv29hm0000gp/T/ipykernel_14520/4142700082.py:1: DtypeWarning: Columns (364,366,367,370,371) have mixed types. Specify dtype option on import or set low_memory=False.
#   unfil_tce_tbl = pd.read_csv(tce_tbl_fp)

# %% [markdown]
# ### Investigating Neg Dispositions (NTP, NEB, NPC) overlap w/ Pos Dispositions (EB, KP, CP) at the target

# %%
t_groups = tce_tbl.groupby(["target_id"])

# %%
print(len(t_groups))
# Out:
# 17186

# %% [markdown]
# Filter for target stars that have both Pos (CP/KP/EB) and Neg (NTP/NEB/NPC) disposition TCEs

# %%
mixed_t_groups = t_groups.filter(
    lambda g: 
        (np.isin(np.array(["EB", "CP", "KP"]), g["disposition"].unique()).any())
        and 
        (np.isin(np.array(["NTP", "NEB", "NPC"]), g["disposition"].unique()).any())
).groupby(["target_id"])

# %%
print(len(mixed_t_groups))
mixed_targets = []
mixed_targets_by_disp = defaultdict(list)
for (t,), g in mixed_t_groups:
    print(g[["target_id", "sector_run", "tce_uid", "disposition"]])
    mixed_targets.append(t)
    mixed_targets_by_disp[tuple(list(g["disposition"]))].append(t)
# Out:
# 1289
#         target_id sector_run         tce_uid disposition
# 141411     120016         38    120016-1-S38         NTP
# 141414     120016       1-65  120016-3-S1-65          EB
#         target_id sector_run      tce_uid disposition
# 144578     737546          5  737546-1-S5          EB
# 144579     737546          5  737546-2-S5         NTP
#         target_id sector_run       tce_uid disposition
# 144694    1450518          5  1450518-1-S5         NTP
# 144695    1450518          5  1450518-2-S5          EB
# 144696    1450518          5  1450518-3-S5         NTP
#        target_id sector_run          tce_uid disposition
# 89812    2020964          8     2020964-1-S8          EB
# 89813    2020964          8     2020964-2-S8         NTP
# 89815    2020964         61    2020964-1-S61          EB
# 89816    2020964       1-65  2020964-1-S1-65          EB
#        target_id sector_run        tce_uid disposition
# 23053    3034524         19  3034524-1-S19          EB
# 23054    3034524         19  3034524-2-S19         NTP
#        target_id sector_run           tce_uid disposition
# 19073    3816260         43     3816260-1-S43          EB
# 19077    3816260          3      3816260-1-S3          EB
# 19078    3816260          3      3816260-2-S3         NTP
# 19079    3816260       1-46   3816260-1-S1-46          EB
# 19081    3816260      42-43  3816260-1-S42-43          EB
#         target_id sector_run          tce_uid disposition
# 19085     3921749         43    3921749-2-S43          EB
# 19091     3921749         30    3921749-2-S30         NTP
# 19092     3921749          3     3921749-1-S3         NTP
# 200770    3921749       1-36  3921749-2-S1-36         NTP
#         target_id sector_run          tce_uid disposition
# 119901    4723156         31    4723156-2-S31          EB
# 119902    4723156         31    4723156-3-S31         NTP
# 200914    4723156       1-36  4723156-3-S1-36         NTP
#         target_id sector_run          tce_uid disposition
# 89411     5092088         35    5092088-1-S35         NTP
# 89412     5092088          9     5092088-1-S9          EB
# 89414     5092088         36    5092088-1-S36          EB
# 89415     5092088         62    5092088-1-S62          EB
# 89419     5092088        1-9   5092088-1-S1-9          EB
# 205225    5092088       1-36  5092088-2-S1-36         NTP
#        target_id sector_run        tce_uid disposition
# 87954    5205367         53  5205367-1-S53          EB
# 87956    5205367         26  5205367-1-S26         NTP
# 87957    5205367         26  5205367-2-S26         NTP
#        target_id sector_run         tce_uid disposition
# 89426    5703872          8    5703872-1-S8         NTP
# 89427    5703872          9    5703872-1-S9          EB
# 89432    5703872        1-9  5703872-1-S1-9          EB
#         target_id sector_run          tce_uid disposition
# 138704    5981829         10    5981829-1-S10          EB
# 138705    5981829         10    5981829-2-S10         NTP
# 138706    5981829         64    5981829-1-S64          EB
# 138711    5981829       1-65  5981829-2-S1-65          EB
#         target_id sector_run       tce_uid disposition
# 133050    6518047          7  6518047-1-S7          EB
# 133051    6518047          7  6518047-2-S7         NTP
#         target_id sector_run       tce_uid disposition
# 133464    7211118          7  7211118-1-S7          EB
# 133465    7211118          7  7211118-2-S7         NTP
#         target_id sector_run         tce_uid disposition
# 140275    7695666          4    7695666-1-S4         NTP
# 140276    7695666          4    7695666-2-S4         NTP
# 140277    7695666          5    7695666-1-S5         NTP
# 140278    7695666          5    7695666-2-S5         NTP
# 140279    7695666        1-6  7695666-1-S1-6          EB
# 140281    7695666        1-6  7695666-3-S1-6         NTP
# 140282    7695666        1-6  7695666-4-S1-6         NTP
#        target_id sector_run           tce_uid disposition
# 51185    7854182         40     7854182-1-S40          EB
# 51186    7854182         40     7854182-2-S40         NTP
# 51187    7854182         54     7854182-1-S54          EB
# 51189    7854182         41     7854182-1-S41          EB
# 51190    7854182         41     7854182-2-S41         NTP
# 51191    7854182         52     7854182-1-S52          EB
# 51193    7854182         53     7854182-1-S53          EB
# 51195    7854182         26     7854182-1-S26          EB
# 51196    7854182         26     7854182-2-S26         NTP
# 51197    7854182         25     7854182-1-S25          EB
# 51198    7854182      14-26  7854182-1-S14-26          EB
# 51199    7854182      14-26  7854182-2-S14-26         NTP
# 51200    7854182      14-41  7854182-1-S14-41          EB
# 51203    7854182      14-55  7854182-1-S14-55          EB
#         target_id sector_run        tce_uid disposition
# 100223    8245065         21  8245065-1-S21          EB
# 100224    8245065         21  8245065-2-S21         NTP
#        target_id sector_run           tce_uid disposition
# 74675    8624617         25     8624617-1-S25          EB
# 74677    8624617         25     8624617-3-S25         NTP
# 74682    8624617      14-26  8624617-2-S14-26          EB
#         target_id sector_run           tce_uid disposition
# 100414    8677671         21     8677671-1-S21          EB
# 100415    8677671         21     8677671-2-S21         NTP
# 100416    8677671         48     8677671-1-S48          EB
# 100418    8677671      14-50  8677671-1-S14-50          EB
#        target_id sector_run           tce_uid disposition
# 78681    9036901         50     9036901-1-S50          EB
# 78682    9036901         23     9036901-1-S23          EB
# 78683    9036901         24     9036901-1-S24          EB
# 78684    9036901      14-26  9036901-1-S14-26          EB
# 78685    9036901      14-26  9036901-2-S14-26         NTP
#         target_id sector_run        tce_uid disposition
# 113309    9461737         22  9461737-1-S22          EB
# 113310    9461737         22  9461737-2-S22         NTP
#         target_id sector_run           tce_uid disposition
# 113855    9473243         26     9473243-1-S26          EB
# 113857    9473243         25     9473243-1-S25          EB
# 113858    9473243      14-26  9473243-1-S14-26          EB
# 113860    9473243      14-26  9473243-3-S14-26         NTP
#         target_id sector_run           tce_uid disposition
# 113863    9825731         26     9825731-1-S26          EB
# 113864    9825731         26     9825731-2-S26         NTP
# 113865    9825731         25     9825731-1-S25          EB
# 113866    9825731      14-26  9825731-1-S14-26          EB
#         target_id sector_run          tce_uid disposition
# 119952    9945183         31    9945183-1-S31          EB
# 119953    9945183         31    9945183-2-S31         NTP
# 119954    9945183         31    9945183-3-S31         NTP
# 119955    9945183          4     9945183-1-S4          EB
# 119956    9945183          4     9945183-2-S4         NTP
# 200955    9945183       1-36  9945183-1-S1-36          EB
# 200956    9945183       1-36  9945183-2-S1-36         NTP
# 200957    9945183       1-36  9945183-3-S1-36         NTP
# 200958    9945183       1-36  9945183-4-S1-36         NTP
#        target_id sector_run            tce_uid disposition
# 87178   10057647         20     10057647-1-S20          EB
# 87179   10057647         20     10057647-2-S20         NTP
# 87180   10057647      14-50  10057647-1-S14-50          EB
#        target_id sector_run            tce_uid disposition
# 47988   10467747         40     10467747-1-S40         NTP
# 47989   10467747         40     10467747-2-S40         NTP
# 47994   10467747         26     10467747-1-S26          EB
# 47996   10467747      14-41  10467747-1-S14-41          EB
#         target_id sector_run           tce_uid disposition
# 115295   11286209         32    11286209-1-S32          EB
# 115296   11286209          6     11286209-1-S6          EB
# 115297   11286209          6     11286209-2-S6         NTP
# 201695   11286209       1-36  11286209-2-S1-36         NTP
#         target_id sector_run           tce_uid disposition
# 125701   11487334         30    11487334-1-S30         NTP
# 125702   11487334          3     11487334-1-S3         NTP
# 200868   11487334       1-36  11487334-1-S1-36          EB
# 200869   11487334       1-36  11487334-2-S1-36         NTP
# 200870   11487334       1-36  11487334-3-S1-36         NTP
#        target_id sector_run            tce_uid disposition
# 64781   11704852         41     11704852-2-S41         NTP
# 64782   11704852         15     11704852-1-S15          EB
# 64784   11704852      14-55  11704852-1-S14-55          EB
#        target_id sector_run            tce_uid disposition
# 99389   11799874         20     11799874-1-S20          EB
# 99391   11799874         20     11799874-3-S20         NTP
# 99392   11799874         60     11799874-1-S60          EB
# 99393   11799874      14-60  11799874-1-S14-60          EB
#        target_id sector_run        tce_uid disposition
# 89435   12012992          8  12012992-1-S8          EB
# 89436   12012992          8  12012992-2-S8         NTP
#        target_id sector_run            tce_uid disposition
# 64794   12494582         55     12494582-1-S55          EB
# 64795   12494582         41     12494582-1-S41          EB
# 64796   12494582         41     12494582-2-S41         NTP
# 64797   12494582         15     12494582-1-S15          EB
# 64798   12494582         15     12494582-2-S15         NTP
# 64799   12494582         15     12494582-3-S15          EB
# 64800   12494582         14     12494582-1-S14          EB
# 64801   12494582      14-19  12494582-1-S14-19          EB
# 64803   12494582      14-41  12494582-1-S14-41          EB
# 64807   12494582      14-55  12494582-1-S14-55          EB
#         target_id sector_run           tce_uid disposition
# 119968   12631605         31    12631605-1-S31          EB
# 119969   12631605         31    12631605-2-S31         NTP
# 119970   12631605          4     12631605-1-S4          EB
# 119971   12631605          4     12631605-2-S4         NTP
# 200964   12631605       1-36  12631605-1-S1-36          EB
#         target_id sector_run           tce_uid disposition
# 25847    12723924         28    12723924-1-S28         NTP
# 25848    12723924          2     12723924-1-S2          EB
# 200497   12723924       1-36  12723924-1-S1-36          EB
#         target_id sector_run            tce_uid disposition
# 121961   12824209         25     12824209-1-S25          EB
# 121962   12824209         18     12824209-1-S18          EB
# 121963   12824209         58     12824209-1-S58          EB
# 121965   12824209         59     12824209-1-S59          EB
# 121967   12824209      14-26  12824209-1-S14-26          EB
# 121968   12824209      14-26  12824209-2-S14-26         NTP
# 121971   12824209      14-60  12824209-1-S14-60          EB
#        target_id sector_run            tce_uid disposition
# 64824   12915124         55     12915124-1-S55          EB
# 64826   12915124         55     12915124-3-S55          EB
# 64827   12915124         41     12915124-1-S41          EB
# 64828   12915124         41     12915124-2-S41         NTP
# 64829   12915124         15     12915124-1-S15          EB
# 64830   12915124         15     12915124-2-S15         NTP
# 64831   12915124         14     12915124-1-S14          EB
# 64832   12915124         14     12915124-2-S14         NTP
# 64834   12915124      14-19  12915124-1-S14-19          EB
# 64836   12915124      14-19  12915124-3-S14-19          EB
# 64837   12915124      14-41  12915124-1-S14-41          EB
# 64838   12915124      14-41  12915124-2-S14-41          EB
# 64839   12915124      14-55  12915124-1-S14-55          EB
#         target_id sector_run           tce_uid disposition
# 115721   13062255         32    13062255-1-S32          EB
# 115722   13062255          5     13062255-1-S5          EB
# 201522   13062255       1-36  13062255-1-S1-36          EB
# 201524   13062255       1-36  13062255-3-S1-36         NTP
#         target_id sector_run        tce_uid disposition
# 144585   13135572          5  13135572-1-S5          EB
# 144586   13135572          5  13135572-2-S5         NTP
#         target_id sector_run           tce_uid disposition
# 116490   13957444         32    13957444-1-S32          EB
# 116492   13957444          5     13957444-1-S5          EB
# 116493   13957444          5     13957444-2-S5         NTP
# 201680   13957444       1-36  13957444-1-S1-36          EB
#        target_id sector_run            tce_uid disposition
# 64883   14207118         55     14207118-1-S55          EB
# 64885   14207118         41     14207118-1-S41          EB
# 64886   14207118         41     14207118-2-S41         NTP
# 64887   14207118         15     14207118-1-S15          EB
# 64889   14207118         14     14207118-1-S14          EB
# 64890   14207118         14     14207118-2-S14         NTP
# 64891   14207118      14-19  14207118-1-S14-19          EB
# 64893   14207118      14-41  14207118-1-S14-41          EB
#        target_id sector_run         tce_uid disposition
# 64916   14842303         41  14842303-1-S41         NTP
# 64918   14842303         15  14842303-1-S15         NTP
# 64919   14842303         15  14842303-2-S15          EB
#         target_id sector_run         tce_uid disposition
# 138901   15445546         10  15445546-1-S10          EB
# 138902   15445546         10  15445546-2-S10         NTP
#         target_id sector_run           tce_uid disposition
# 108129   15445551         37    15445551-1-S37          KP
# 108130   15445551         37    15445551-2-S37         NTP
# 108131   15445551         10    15445551-1-S10          KP
# 108133   15445551         11    15445551-1-S11          KP
# 108135   15445551       1-13  15445551-1-S1-13          KP
# 188865   15445551       1-39  15445551-1-S1-39          KP
#         target_id sector_run         tce_uid disposition
# 131744   15613315         17  15613315-1-S17          EB
# 131745   15613315         17  15613315-2-S17         NTP
#        target_id sector_run         tce_uid disposition
# 99079   16485009         20  16485009-1-S20          EB
# 99080   16485009         20  16485009-2-S20         NTP
#        target_id sector_run            tce_uid disposition
# 64958   16728252         41     16728252-2-S41         NTP
# 64959   16728252         41     16728252-3-S41         NTP
# 64960   16728252         15     16728252-1-S15          EB
# 64961   16728252         15     16728252-2-S15         NTP
# 64962   16728252         14     16728252-1-S14          EB
# 64963   16728252         14     16728252-2-S14         NTP
# 64964   16728252      14-19  16728252-1-S14-19          EB
# 64966   16728252      14-41  16728252-1-S14-41          EB
#        target_id sector_run            tce_uid disposition
# 64974   16740101         55     16740101-1-S55          KP
# 64976   16740101         41     16740101-1-S41          KP
# 64978   16740101         15     16740101-1-S15          KP
# 64979   16740101         15     16740101-2-S15         NTP
# 64980   16740101         14     16740101-1-S14          KP
# 64981   16740101         14     16740101-2-S14         NTP
# 64982   16740101      14-19  16740101-1-S14-19          KP
# 64984   16740101      14-41  16740101-1-S14-41          KP
# 64986   16740101      14-55  16740101-1-S14-55          KP
#         target_id sector_run            tce_uid disposition
# 113877   18269802         26     18269802-1-S26          EB
# 113878   18269802         25     18269802-1-S25          EB
# 113879   18269802         25     18269802-2-S25         NTP
# 113880   18269802      14-26  18269802-1-S14-26          EB
# 113881   18269802      14-26  18269802-2-S14-26         NTP
#        target_id sector_run            tce_uid disposition
# 81691   18271803         52     18271803-1-S52          EB
# 81693   18271803         53     18271803-1-S53          EB
# 81699   18271803         26     18271803-1-S26          EB
# 81700   18271803         26     18271803-2-S26         NTP
# 81701   18271803         25     18271803-1-S25          EB
# 81702   18271803         25     18271803-2-S25         NTP
# 81703   18271803      14-26  18271803-1-S14-26          EB
# 81704   18271803      14-26  18271803-2-S14-26         NTP
# 81705   18271803      14-55  18271803-1-S14-55          EB
#         target_id sector_run            tce_uid disposition
# 113894   18534775         26     18534775-1-S26          EB
# 113895   18534775         26     18534775-2-S26         NTP
# 113896   18534775         25     18534775-1-S25          EB
# 113897   18534775         25     18534775-2-S25         NTP
# 113898   18534775      14-26  18534775-1-S14-26          EB
# 113899   18534775      14-26  18534775-2-S14-26         NTP
#         target_id sector_run           tce_uid disposition
# 70464    18914916         34    18914916-3-S34         NTP
# 70465    18914916          7     18914916-1-S7         NTP
# 202178   18914916       1-36  18914916-1-S1-36          EB
#         target_id sector_run          tce_uid disposition
# 138323   20095466          6    20095466-1-S6          EB
# 138324   20095466          5    20095466-1-S5          EB
# 138325   20095466        1-6  20095466-1-S1-6          EB
# 138326   20095466        1-6  20095466-2-S1-6         NTP
#         target_id sector_run        tce_uid disposition
# 144708   20176492          5  20176492-1-S5          EB
# 144709   20176492          5  20176492-2-S5         NTP
# 144710   20176492          5  20176492-3-S5         NTP
#        target_id sector_run         tce_uid disposition
# 74801   20212631         51  20212631-1-S51          EB
# 74805   20212631         23  20212631-1-S23          EB
# 74806   20212631         23  20212631-2-S23         NTP
# 74807   20212631         24  20212631-1-S24          EB
#         target_id sector_run            tce_uid disposition
# 114219   21126323         26     21126323-1-S26          EB
# 114221   21126323         25     21126323-1-S25          EB
# 114223   21126323      14-26  21126323-1-S14-26          EB
# 114224   21126323      14-26  21126323-2-S14-26         NTP
# 114226   21126323      14-26  21126323-4-S14-26         NTP
#         target_id sector_run        tce_uid disposition
# 144714   21729403          5  21729403-1-S5         NTP
# 144715   21729403          5  21729403-2-S5          EB
#         target_id sector_run            tce_uid disposition
# 113323   22017780      14-23  22017780-2-S14-23         NTP
# 113325   22017780      14-50  22017780-2-S14-50          EB
#         target_id sector_run           tce_uid disposition
# 139102   22390773         10    22390773-1-S10          EB
# 139103   22390773         10    22390773-2-S10         NTP
# 139104   22390773         64    22390773-1-S64          EB
# 139106   22390773       1-65  22390773-1-S1-65          EB
#         target_id sector_run           tce_uid disposition
# 95616    22529346         34    22529346-1-S34          KP
# 95617    22529346         33    22529346-1-S33          KP
# 95618    22529346          7     22529346-1-S7          KP
# 95619    22529346          7     22529346-2-S7         NTP
# 95620    22529346         61    22529346-1-S61          KP
# 95621    22529346       1-65  22529346-1-S1-65          KP
# 204027   22529346       1-36  22529346-1-S1-36          KP
#        target_id sector_run           tce_uid disposition
# 90254   22538139          8     22538139-1-S8          EB
# 90255   22538139          8     22538139-2-S8         NTP
# 90256   22538139         61    22538139-1-S61          EB
# 90258   22538139       1-65  22538139-1-S1-65          EB
#        target_id sector_run         tce_uid disposition
# 95660   22937402         34  22937402-1-S34          EB
# 95663   22937402          7   22937402-1-S7         NTP
# 95664   22937402          7   22937402-2-S7          EB
#         target_id sector_run        tce_uid disposition
# 139981   23221002          4  23221002-1-S4         NTP
# 139982   23221002          4  23221002-2-S4          EB
#         target_id sector_run           tce_uid disposition
# 104110   23559851          9     23559851-1-S9          EB
# 104112   23559851         10    23559851-1-S10          EB
# 104113   23559851         10    23559851-2-S10         NTP
# 104116   23559851       1-13  23559851-1-S1-13          EB
# 104117   23559851       1-13  23559851-2-S1-13         NTP
# 104118   23559851       1-65  23559851-1-S1-65          EB
#         target_id sector_run           tce_uid disposition
# 136285   24133365         12    24133365-1-S12          EB
# 136287   24133365         38    24133365-1-S38          EB
# 136288   24133365         38    24133365-2-S38         NTP
# 187156   24133365       1-39  24133365-1-S1-39          EB
#         target_id sector_run         tce_uid disposition
# 136289   24194061         12  24194061-1-S12          EB
# 136290   24194061         12  24194061-2-S12         NTP
# 136291   24194061         65  24194061-1-S65          EB
#         target_id sector_run        tce_uid disposition
# 144716   24433067          5  24433067-1-S5          EB
# 144717   24433067          5  24433067-2-S5         NTP
# 144718   24433067          5  24433067-3-S5         NTP
#         target_id sector_run           tce_uid disposition
# 116247   24450633         32    24450633-1-S32         NTP
# 116248   24450633         32    24450633-2-S32         NTP
# 116249   24450633         32    24450633-3-S32          EB
# 116250   24450633         33    24450633-1-S33          EB
# 116251   24450633          6     24450633-1-S6          EB
# 116253   24450633          5     24450633-1-S5          EB
# 116255   24450633        1-6   24450633-1-S1-6          EB
# 204991   24450633       1-36  24450633-1-S1-36          EB
# 204992   24450633       1-36  24450633-2-S1-36         NTP
#         target_id sector_run           tce_uid disposition
# 130215   24704862        1-2   24704862-1-S1-2          EB
# 203332   24704862       1-36  24704862-1-S1-36         NTP
#         target_id sector_run           tce_uid disposition
# 89468    24733359          8     24733359-1-S8          EB
# 89470    24733359         35    24733359-2-S35          EB
# 89471    24733359          9     24733359-1-S9          EB
# 89473    24733359         62    24733359-1-S62          EB
# 89477    24733359        1-9   24733359-1-S1-9          EB
# 204080   24733359       1-36  24733359-2-S1-36         NTP
#     target_id sector_run         tce_uid disposition
# 69   24935204         17  24935204-1-S17          EB
# 70   24935204         17  24935204-2-S17         NTP
#        target_id sector_run           tce_uid disposition
# 89481   24972851          8     24972851-1-S8          EB
# 89482   24972851          8     24972851-2-S8         NTP
# 89483   24972851          9     24972851-1-S9          EB
# 89484   24972851          9     24972851-2-S9         NTP
# 89485   24972851          9     24972851-3-S9          EB
# 89486   24972851         62    24972851-1-S62          EB
# 89488   24972851       1-65  24972851-1-S1-65          EB
# 89491   24972851        1-9   24972851-1-S1-9          EB
# 89493   24972851        1-9   24972851-3-S1-9          EB
#         target_id sector_run           tce_uid disposition
# 31947    25078924          8     25078924-1-S8          EB
# 31948    25078924          8     25078924-2-S8         NTP
# 31949    25078924          8     25078924-3-S8         NTP
# 31950    25078924         34    25078924-1-S34          EB
# 31952    25078924         35    25078924-1-S35          EB
# ...           ...        ...               ...         ...
# 198578   25078924       1-39  25078924-1-S1-39          EB
# 198579   25078924       1-39  25078924-2-S1-39         NTP
# 198580   25078924       1-39  25078924-3-S1-39         NTP
# 198581   25078924       1-36  25078924-1-S1-36          EB
# 198582   25078924       1-36  25078924-2-S1-36         NTP
#
# [64 rows x 4 columns]
#         target_id sector_run           tce_uid disposition
# 32089    25195864         64    25195864-1-S64          EB
# 32092    25195864       1-65  25195864-1-S1-65          EB
# 195633   25195864       1-39  25195864-1-S1-39          EB
# 195634   25195864       1-39  25195864-2-S1-39         NTP
# 195636   25195864       1-36  25195864-2-S1-36         NTP
# 195637   25195864       1-36  25195864-3-S1-36         NTP
#        target_id sector_run         tce_uid disposition
# 20351   26533207         18  26533207-1-S18          EB
# 20352   26533207         18  26533207-2-S18         NTP
#        target_id sector_run            tce_uid disposition
# 26858   26656583         40     26656583-1-S40         NTP
# 26859   26656583         40     26656583-2-S40         NTP
# 26864   26656583         41     26656583-1-S41         NTP
# 26865   26656583         41     26656583-2-S41         NTP
# 26866   26656583         15     26656583-1-S15          EB
# 26868   26656583         14     26656583-1-S14          EB
# 26870   26656583      14-19  26656583-1-S14-19          EB
# 26872   26656583      14-41  26656583-1-S14-41          EB
# 26874   26656583      14-55  26656583-1-S14-55          EB
# 26878   26656583      14-60  26656583-1-S14-60          EB
#      target_id sector_run            tce_uid disposition
# 163   26801525         57     26801525-1-S57          EB
# 167   26801525         24     26801525-1-S24          EB
# 169   26801525         24     26801525-3-S24         NTP
# 170   26801525         24     26801525-4-S24         NTP
# 171   26801525         24     26801525-5-S24         NTP
# 172   26801525         24     26801525-6-S24         NTP
# 173   26801525         17     26801525-1-S17          EB
# 174   26801525         17     26801525-2-S17         NTP
# 175   26801525         17     26801525-3-S17         NTP
# 176   26801525         17     26801525-4-S17         NTP
# 177   26801525      14-26  26801525-1-S14-26          EB
# 179   26801525      14-26  26801525-3-S14-26         NTP
# 180   26801525      14-26  26801525-4-S14-26         NTP
# 181   26801525      14-26  26801525-5-S14-26         NTP
# 182   26801525      14-26  26801525-6-S14-26         NTP
# 183   26801525      14-60  26801525-1-S14-60          EB
#         target_id sector_run            tce_uid disposition
# 131676   27491137      14-23  27491137-1-S14-23         NTP
# 131678   27491137      14-50  27491137-1-S14-50          CP
#        target_id sector_run            tce_uid disposition
# 27081   27844498         56     27844498-1-S56          EB
# 27082   27844498         54     27844498-1-S54          EB
# 27084   27844498         55     27844498-1-S55          EB
# 27086   27844498         41     27844498-1-S41          EB
# 27087   27844498         41     27844498-2-S41         NTP
# 27088   27844498         15     27844498-1-S15          EB
# 27089   27844498         14     27844498-1-S14          EB
# 27091   27844498      14-19  27844498-1-S14-19          EB
# 27093   27844498      14-41  27844498-1-S14-41          EB
# 27095   27844498      14-55  27844498-1-S14-55          EB
# 27100   27844498      14-60  27844498-1-S14-60          EB
#        target_id sector_run            tce_uid disposition
# 27105   27845677         41     27845677-1-S41         NTP
# 27106   27845677         15     27845677-1-S15         NTP
# 27107   27845677         14     27845677-1-S14         NTP
# 27114   27845677      14-60  27845677-1-S14-60          EB
#        target_id sector_run            tce_uid disposition
# 19866   28351918         43     28351918-1-S43          EB
# 19869   28351918         42     28351918-1-S42          EB
# 19872   28351918         17     28351918-1-S17          EB
# 19873   28351918         17     28351918-2-S17         NTP
# 19876   28351918      42-43  28351918-1-S42-43          EB
#         target_id sector_run            tce_uid disposition
# 131800   28391714         17     28391714-1-S17          EB
# 131801   28391714         17     28391714-2-S17         NTP
# 131805   28391714      14-60  28391714-1-S14-60          EB
#         target_id sector_run         tce_uid disposition
# 122302   28498786         19  28498786-1-S19          EB
# 122303   28498786         19  28498786-2-S19         NTP
#         target_id sector_run            tce_uid disposition
# 123487   28763683         17     28763683-2-S17         NTP
# 123490   28763683      14-60  28763683-1-S14-60          EB
#        target_id sector_run            tce_uid disposition
# 20388   29053989         43     29053989-1-S43          EB
# 20390   29053989         42     29053989-1-S42          EB
# 20392   29053989         44     29053989-1-S44          EB
# 20395   29053989         18     29053989-1-S18          EB
# 20396   29053989         18     29053989-2-S18         NTP
# 20397   29053989      42-46  29053989-1-S42-46          EB
# 20401   29053989       1-46   29053989-1-S1-46          EB
# 20404   29053989      42-43  29053989-1-S42-43          EB
#        target_id sector_run         tce_uid disposition
# 47090   29706981         40  29706981-1-S40         NTP
# 47093   29706981         14  29706981-1-S14          EB
#         target_id sector_run           tce_uid disposition
# 32126    29778064         34    29778064-1-S34          EB
# 32127    29778064         34    29778064-2-S34         NTP
# 32128    29778064         35    29778064-1-S35          EB
# 32129    29778064         35    29778064-2-S35         NTP
# 32130    29778064          9     29778064-1-S9          EB
# 32131    29778064          9     29778064-2-S9         NTP
# 32132    29778064         37    29778064-1-S37          EB
# 32133    29778064         37    29778064-2-S37         NTP
# 32134    29778064         36    29778064-1-S36          EB
# 32135    29778064         32    29778064-1-S32          EB
# 32136    29778064         32    29778064-2-S32         NTP
# 32137    29778064         33    29778064-1-S33          EB
# 32138    29778064         33    29778064-2-S33         NTP
# 32139    29778064         27    29778064-1-S27          EB
# 32140    29778064         27    29778064-2-S27         NTP
# 32141    29778064         31    29778064-1-S31          EB
# 32142    29778064         31    29778064-2-S31         NTP
# 32143    29778064         30    29778064-1-S30          EB
# 32144    29778064         30    29778064-2-S30         NTP
# 32145    29778064         29    29778064-1-S29          EB
# 32146    29778064         29    29778064-2-S29         NTP
# 32147    29778064         28    29778064-1-S28          EB
# 32148    29778064         28    29778064-2-S28         NTP
# 32149    29778064         13    29778064-1-S13          EB
# 32150    29778064         13    29778064-2-S13         NTP
# 32151    29778064         12    29778064-1-S12          EB
# 32152    29778064         12    29778064-2-S12         NTP
# 32153    29778064         10    29778064-1-S10          EB
# 32154    29778064         10    29778064-2-S10         NTP
# 32155    29778064         38    29778064-1-S38          EB
# 32156    29778064         38    29778064-2-S38         NTP
# 32157    29778064         11    29778064-1-S11          EB
# 32158    29778064         11    29778064-2-S11         NTP
# 32159    29778064         62    29778064-1-S62          EB
# 32161    29778064         63    29778064-1-S63          EB
# 32163    29778064         61    29778064-1-S61          EB
# 32165    29778064         64    29778064-1-S64          EB
# 32167    29778064         65    29778064-1-S65          EB
# 32169    29778064         67    29778064-1-S67          EB
# 32171    29778064         66    29778064-1-S66          EB
# 32173    29778064       1-13  29778064-1-S1-13          EB
# 32174    29778064       1-13  29778064-2-S1-13         NTP
# 32175    29778064       1-65  29778064-1-S1-65          EB
# 195841   29778064       1-39  29778064-1-S1-39          EB
# 195842   29778064       1-39  29778064-2-S1-39         NTP
# 195843   29778064       1-39  29778064-3-S1-39         NTP
# 195844   29778064       1-36  29778064-1-S1-36          EB
# 195845   29778064       1-36  29778064-2-S1-36         NTP
#         target_id sector_run           tce_uid disposition
# 106350   29781292          9     29781292-1-S9         NTP
# 106352   29781292        1-3   29781292-1-S1-3          CP
# 106355   29781292        1-6   29781292-1-S1-6          CP
# 106356   29781292        1-6   29781292-2-S1-6          CP
# 106357   29781292        1-6   29781292-3-S1-6          CP
# 106358   29781292       1-13  29781292-1-S1-13          CP
# 106359   29781292       1-13  29781292-2-S1-13          CP
# 106360   29781292       1-13  29781292-3-S1-13          CP
# 106361   29781292       1-65  29781292-1-S1-65          CP
# 106362   29781292       1-65  29781292-2-S1-65          CP
# 106363   29781292       1-65  29781292-3-S1-65          CP
# 106364   29781292        1-9   29781292-1-S1-9          CP
# 106365   29781292        1-9   29781292-2-S1-9          CP
# 106366   29781292        1-9   29781292-3-S1-9          CP
# 198639   29781292       1-39  29781292-1-S1-39          CP
# 198640   29781292       1-39  29781292-2-S1-39          CP
# 198641   29781292       1-39  29781292-3-S1-39          CP
# 198642   29781292       1-36  29781292-1-S1-36          CP
# 198643   29781292       1-36  29781292-2-S1-36          CP
# 198644   29781292       1-36  29781292-3-S1-36          CP
#         target_id sector_run           tce_uid disposition
# 125468   29847695         30    29847695-1-S30          EB
# 125470   29847695          3     29847695-1-S3          EB
# 125471   29847695          3     29847695-2-S3         NTP
# 200738   29847695       1-36  29847695-1-S1-36          EB
#         target_id sector_run           tce_uid disposition
# 104121   29914747          9     29914747-1-S9          EB
# 104122   29914747          9     29914747-2-S9         NTP
# 104123   29914747         10    29914747-1-S10          EB
# 104124   29914747         10    29914747-2-S10         NTP
# 104125   29914747         63    29914747-1-S63          EB
# 104127   29914747       1-13  29914747-1-S1-13          EB
# 104128   29914747       1-13  29914747-2-S1-13         NTP
# 104129   29914747       1-65  29914747-1-S1-65          EB
#         target_id sector_run           tce_uid disposition
# 32321    30034081          8     30034081-1-S8          EB
# 32322    30034081          8     30034081-2-S8         NTP
# 32323    30034081          8     30034081-3-S8         NTP
# 32324    30034081         34    30034081-1-S34          EB
# 32325    30034081         34    30034081-2-S34         NTP
# ...           ...        ...               ...         ...
# 196555   30034081       1-39  30034081-1-S1-39          EB
# 196556   30034081       1-39  30034081-2-S1-39         NTP
# 196558   30034081       1-39  30034081-4-S1-39         NTP
# 196559   30034081       1-36  30034081-1-S1-36          EB
# 196560   30034081       1-36  30034081-2-S1-36          EB
#
# [69 rows x 4 columns]
#         target_id sector_run           tce_uid disposition
# 135994   30450412         12    30450412-1-S12          EB
# 135995   30450412         39    30450412-1-S39          EB
# 186563   30450412       1-39  30450412-2-S1-39         NTP
# 186564   30450412       1-39  30450412-3-S1-39         NTP
# 186565   30450412       1-39  30450412-4-S1-39         NTP
# 186566   30450412       1-39  30450412-5-S1-39         NTP
# 186567   30450412       1-39  30450412-6-S1-39         NTP
#         target_id sector_run           tce_uid disposition
# 89974    30562668          8     30562668-1-S8          EB
# 89976    30562668         35    30562668-1-S35          EB
# 89978    30562668          9     30562668-1-S9          EB
# 89980    30562668         36    30562668-1-S36          EB
# 89981    30562668         36    30562668-2-S36         NTP
# 89982    30562668        1-9   30562668-1-S1-9          EB
# 205244   30562668       1-36  30562668-1-S1-36          EB
#        target_id sector_run           tce_uid disposition
# 32299   31107108          6     31107108-1-S6          EB
# 32300   31107108          6     31107108-2-S6         NTP
# 32301   31107108          4     31107108-1-S4         NTP
# 32302   31107108          5     31107108-1-S5         NTP
# 32303   31107108         62    31107108-1-S62          EB
# 32304   31107108         63    31107108-1-S63          EB
# 32306   31107108         64    31107108-1-S64          EB
# 32311   31107108         67    31107108-2-S67          EB
# 32312   31107108         66    31107108-1-S66          EB
# 32313   31107108        1-6   31107108-1-S1-6          EB
# 32315   31107108       1-65  31107108-2-S1-65          EB
#         target_id sector_run         tce_uid disposition
# 145209   31134762         11  31134762-1-S11          EB
# 145210   31134762         11  31134762-2-S11         NTP
#         target_id sector_run           tce_uid disposition
# 93401    31273263         35    31273263-1-S35         NTP
# 93402    31273263          9     31273263-1-S9         NTP
# 93404    31273263         36    31273263-1-S36         NTP
# 93405    31273263         32    31273263-1-S32         NTP
# 93406    31273263         33    31273263-1-S33         NTP
# 93407    31273263         31    31273263-1-S31         NTP
# 93408    31273263         29    31273263-1-S29         NTP
# 93409    31273263          1     31273263-1-S1         NTP
# 93410    31273263         28    31273263-1-S28         NTP
# 93412    31273263          3     31273263-1-S3         NTP
# 93413    31273263          3     31273263-2-S3         NTP
# 93414    31273263         13    31273263-1-S13         NTP
# 93415    31273263         12    31273263-1-S12         NTP
# 93416    31273263          6     31273263-1-S6         NTP
# 93417    31273263          4     31273263-1-S4         NTP
# 93418    31273263         38    31273263-1-S38         NTP
# 93419    31273263         39    31273263-1-S39         NTP
# 93424    31273263        1-3   31273263-1-S1-3          EB
# 93425    31273263        1-2   31273263-1-S1-2          EB
# 93426    31273263        1-6   31273263-1-S1-6          EB
# 93427    31273263       1-13  31273263-1-S1-13          EB
# 93430    31273263       1-65  31273263-1-S1-65          EB
# 93431    31273263        1-9   31273263-1-S1-9          EB
# 196363   31273263       1-39  31273263-1-S1-39          EB
# 196364   31273263       1-36  31273263-1-S1-36          EB
#        target_id sector_run           tce_uid disposition
# 32397   31415131          9     31415131-1-S9         NTP
# 32398   31415131         12    31415131-1-S12         NTP
# 32399   31415131         10    31415131-1-S10         NTP
# 32400   31415131         11    31415131-1-S11         NTP
# 32406   31415131       1-13  31415131-1-S1-13         NTP
# 32407   31415131       1-65  31415131-1-S1-65          EB
#        target_id sector_run          tce_uid disposition
# 31879   31653503          1    31653503-2-S1         NTP
# 31880   31653503          2    31653503-1-S2          EB
# 31882   31653503          3    31653503-1-S3         NTP
# 31884   31653503        1-3  31653503-1-S1-3          EB
# 31886   31653503        1-2  31653503-1-S1-2          EB
#         target_id sector_run         tce_uid disposition
# 134290   31690845         13  31690845-1-S13          EB
# 134291   31690845         13  31690845-2-S13         NTP
# 134292   31690845         13  31690845-3-S13         NTP
#         target_id sector_run           tce_uid disposition
# 89987    31810287          8     31810287-1-S8          EB
# 89989    31810287          8     31810287-3-S8         NTP
# 89990    31810287         35    31810287-1-S35          EB
# 89991    31810287         35    31810287-2-S35         NTP
# 89993    31810287          9     31810287-1-S9          EB
# 89994    31810287          9     31810287-2-S9          EB
# 89996    31810287         36    31810287-1-S36          EB
# 89997    31810287         36    31810287-2-S36         NTP
# 89999    31810287         36    31810287-4-S36         NTP
# 90000    31810287         62    31810287-1-S62          EB
# 90004    31810287         63    31810287-1-S63          EB
# 90006    31810287       1-65  31810287-1-S1-65          EB
# 90010    31810287        1-9   31810287-1-S1-9          EB
# 90012    31810287        1-9   31810287-3-S1-9          EB
# 205248   31810287       1-36  31810287-1-S1-36          EB
# 205249   31810287       1-36  31810287-2-S1-36          EB
# 205250   31810287       1-36  31810287-3-S1-36         NTP
#         target_id sector_run           tce_uid disposition
# 32554    31850842         37    31850842-1-S37          EB
# 32556    31850842         37    31850842-3-S37         NTP
# 32557    31850842         27    31850842-1-S27          EB
# 32559    31850842         27    31850842-3-S27         NTP
# 32560    31850842         30    31850842-1-S30          EB
# 32561    31850842         30    31850842-2-S30         NTP
# 32562    31850842         30    31850842-3-S30         NTP
# 32563    31850842         30    31850842-4-S30         NTP
# 32564    31850842         29    31850842-1-S29          EB
# 32565    31850842         29    31850842-2-S29         NTP
# 32566    31850842         29    31850842-3-S29         NTP
# 32567    31850842         29    31850842-4-S29         NTP
# 32568    31850842         29    31850842-5-S29         NTP
# 32569    31850842          1     31850842-1-S1          EB
# 32571    31850842         28    31850842-1-S28          EB
# 32573    31850842         28    31850842-3-S28          EB
# 32574    31850842          2     31850842-1-S2          EB
# 32576    31850842          2     31850842-3-S2          EB
# 32577    31850842          3     31850842-1-S3          EB
# 32578    31850842          3     31850842-2-S3         NTP
# 32579    31850842          3     31850842-3-S3         NTP
# 32580    31850842          3     31850842-4-S3         NTP
# 32581    31850842         61    31850842-1-S61          EB
# 32584    31850842         64    31850842-1-S64          EB
# 32586    31850842         67    31850842-1-S67          EB
# 32590    31850842        1-3   31850842-1-S1-3          EB
# 32593    31850842        1-2   31850842-1-S1-2          EB
# 32598    31850842       1-65  31850842-1-S1-65          EB
# 191827   31850842       1-39  31850842-1-S1-39          EB
# 191830   31850842       1-36  31850842-1-S1-36          EB
# 191832   31850842       1-36  31850842-3-S1-36         NTP
#         target_id sector_run           tce_uid disposition
# 106398   32000625          9     32000625-1-S9         NTP
# 106399   32000625          1     32000625-1-S1          EB
# 106400   32000625          1     32000625-2-S1         NTP
# 106403   32000625          3     32000625-1-S3         NTP
# 106404   32000625          3     32000625-2-S3         NTP
# 106405   32000625          7     32000625-1-S7         NTP
# 106406   32000625         13    32000625-1-S13          EB
# 106407   32000625         13    32000625-2-S13         NTP
# 106408   32000625          6     32000625-1-S6         NTP
# 106409   32000625         10    32000625-1-S10         NTP
# 106423   32000625       1-13  32000625-1-S1-13         NTP
# 106424   32000625       1-13  32000625-2-S1-13         NTP
# 106425   32000625       1-13  32000625-3-S1-13         NTP
# 106428   32000625        1-9   32000625-1-S1-9          EB
#        target_id sector_run           tce_uid disposition
# 32678   32150630          8     32150630-1-S8          EB
# 32680   32150630          9     32150630-1-S9          EB
# 32682   32150630          1     32150630-1-S1          EB
# 32683   32150630          1     32150630-2-S1         NTP
# 32684   32150630          1     32150630-3-S1         NTP
# 32685   32150630          2     32150630-1-S2          EB
# 32687   32150630          3     32150630-1-S3          EB
# 32688   32150630          3     32150630-2-S3         NTP
# 32689   32150630          3     32150630-3-S3         NTP
# 32690   32150630          7     32150630-1-S7          EB
# 32691   32150630          7     32150630-2-S7         NTP
# 32692   32150630         13    32150630-1-S13          EB
# 32694   32150630         12    32150630-1-S12          EB
# 32696   32150630          6     32150630-1-S6          EB
# 32698   32150630         10    32150630-1-S10          EB
# 32700   32150630          4     32150630-1-S4          EB
# 32701   32150630          4     32150630-2-S4         NTP
# 32702   32150630          4     32150630-3-S4         NTP
# 32703   32150630         11    32150630-1-S11          EB
# 32705   32150630         62    32150630-1-S62          EB
# 32707   32150630         63    32150630-1-S63          EB
# 32709   32150630         61    32150630-1-S61          EB
# 32711   32150630         64    32150630-1-S64          EB
# 32713   32150630         67    32150630-1-S67          EB
# 32715   32150630         66    32150630-1-S66          EB
# 32717   32150630        1-3   32150630-1-S1-3          EB
# 32724   32150630        1-2   32150630-2-S1-2          EB
# 32726   32150630        1-6   32150630-1-S1-6          EB
# 32728   32150630        1-6   32150630-3-S1-6         NTP
# 32729   32150630        1-6   32150630-4-S1-6         NTP
# 32730   32150630        1-6   32150630-5-S1-6         NTP
# 32731   32150630        1-6   32150630-6-S1-6         NTP
# 32732   32150630       1-13  32150630-1-S1-13          EB
# 32733   32150630       1-65  32150630-1-S1-65          EB
# 32739   32150630        1-9   32150630-1-S1-9          EB
#         target_id sector_run        tce_uid disposition
# 132401   32284829          3  32284829-1-S3          EB
# 132403   32284829          3  32284829-3-S3         NTP
#         target_id sector_run           tce_uid disposition
# 86064    32449963         37    32449963-1-S37          EB
# 86066    32449963         37    32449963-3-S37         NTP
# 86067    32449963         10    32449963-1-S10          EB
# 86070    32449963       1-46  32449963-1-S1-46          EB
# 185717   32449963       1-39  32449963-1-S1-39          EB
# 185718   32449963       1-39  32449963-2-S1-39          EB
# 185719   32449963       1-39  32449963-3-S1-39         NTP
#         target_id sector_run           tce_uid disposition
# 115882   32702481         32    32702481-1-S32          EB
# 115883   32702481         32    32702481-2-S32         NTP
# 115884   32702481         32    32702481-3-S32         NTP
# 115885   32702481         32    32702481-4-S32         NTP
# 115886   32702481         33    32702481-1-S33          EB
# 115887   32702481         33    32702481-2-S33         NTP
# 115888   32702481         33    32702481-3-S33         NTP
# 115890   32702481          6     32702481-1-S6          EB
# 115891   32702481          6     32702481-2-S6         NTP
# 115892   32702481          6     32702481-3-S6         NTP
# 115893   32702481          5     32702481-1-S5          EB
# 115894   32702481          5     32702481-2-S5         NTP
# 115895   32702481          5     32702481-3-S5         NTP
# 115896   32702481        1-6   32702481-1-S1-6          EB
# 115897   32702481        1-6   32702481-2-S1-6         NTP
# 115898   32702481        1-6   32702481-3-S1-6         NTP
# 204952   32702481       1-36  32702481-1-S1-36          EB
# 204954   32702481       1-36  32702481-3-S1-36         NTP
# 204955   32702481       1-36  32702481-4-S1-36         NTP
#         target_id sector_run           tce_uid disposition
# 115907   32949762         32    32949762-1-S32          KP
# 115908   32949762         32    32949762-2-S32         NTP
# 115909   32949762         33    32949762-1-S33          KP
# 206481   32949762       1-36  32949762-1-S1-36          KP
# 206482   32949762       1-36  32949762-2-S1-36         NTP
#         target_id sector_run        tce_uid disposition
# 132355   33665328          3  33665328-1-S3          EB
# 132356   33665328          3  33665328-2-S3         NTP
# 132357   33665328          3  33665328-3-S3         NTP
#        target_id sector_run           tce_uid disposition
# 32491   33834253          4     33834253-1-S4          EB
# 32492   33834253          4     33834253-2-S4         NTP
# 32493   33834253          5     33834253-1-S5          EB
# 32494   33834253          5     33834253-2-S5         NTP
# 32495   33834253         62    33834253-1-S62          EB
# 32497   33834253         63    33834253-1-S63          EB
# 32500   33834253         64    33834253-1-S64          EB
# 32502   33834253         65    33834253-1-S65          EB
# 32504   33834253         67    33834253-1-S67          EB
# 32506   33834253         66    33834253-1-S66          EB
# 32507   33834253        1-6   33834253-1-S1-6          EB
# 32509   33834253       1-65  33834253-1-S1-65          EB
#        target_id sector_run           tce_uid disposition
# 32521   33862174          1     33862174-1-S1          EB
# 32523   33862174          5     33862174-1-S5          EB
# 32524   33862174          5     33862174-2-S5         NTP
# 32525   33862174         62    33862174-1-S62          EB
# 32526   33862174         62    33862174-2-S62          EB
# 32527   33862174         63    33862174-1-S63          EB
# 32528   33862174         63    33862174-2-S63          EB
# ...
# 136699  448852739       1-13  448852739-1-S1-13          EB
# 136701  448852739       1-65  448852739-1-S1-65          EB
# 190299  448852739       1-39  448852739-1-S1-39          EB
# 190301  448852739       1-39  448852739-3-S1-39         NTP
#         target_id sector_run         tce_uid disposition
# 144513  450104319          5  450104319-1-S5          EB
# 144514  450104319          5  450104319-2-S5         NTP
#         target_id sector_run            tce_uid disposition
# 137680  452500843         12    452500843-1-S12          EB
# 137681  452500843         10    452500843-1-S10         NTP
# 137682  452500843         11    452500843-1-S11          EB
# 137683  452500843         11    452500843-2-S11         NTP
# 137684  452500843         11    452500843-3-S11         NTP
# 137689  452500843       1-13  452500843-1-S1-13          EB
# 137690  452500843       1-13  452500843-2-S1-13         NTP
# 137692  452500843       1-13  452500843-4-S1-13         NTP
#        target_id sector_run             tce_uid disposition
# 67424  452563490         41     452563490-1-S41          EB
# 67426  452563490         15     452563490-1-S15          EB
# 67427  452563490         15     452563490-2-S15         NTP
# 67428  452563490      14-41  452563490-1-S14-41          EB
#         target_id sector_run            tce_uid disposition
# 137717  452631268         12    452631268-1-S12         NTP
# 137718  452631268         10    452631268-1-S10         NTP
# 137719  452631268         11    452631268-1-S11          EB
# 137724  452631268       1-13  452631268-1-S1-13          EB
# 137726  452631268       1-65  452631268-1-S1-65          EB
#         target_id sector_run            tce_uid disposition
# 94456   452845139         34    452845139-1-S34          EB
# 94457   452845139         34    452845139-2-S34         NTP
# 94458   452845139          7     452845139-1-S7          EB
# 94459   452845139         61    452845139-1-S61          EB
# 94460   452845139       1-65  452845139-1-S1-65          EB
# 202135  452845139       1-36  452845139-1-S1-36          EB
#         target_id sector_run            tce_uid disposition
# 94186   452955107         34    452955107-1-S34          EB
# 94188   452955107          7     452955107-1-S7          EB
# 94189   452955107          7     452955107-2-S7         NTP
# 202072  452955107       1-36  452955107-2-S1-36         NTP
# 202073  452955107       1-36  452955107-3-S1-36         NTP
#        target_id sector_run            tce_uid disposition
# 46996  453095485          9     453095485-1-S9         NTP
# 46997  453095485          9     453095485-2-S9          EB
# 46998  453095485         13    453095485-1-S13          EB
# 46999  453095485         12    453095485-1-S12          EB
# 47000  453095485         12    453095485-2-S12         NTP
# 47001  453095485         11    453095485-1-S11          EB
# 47002  453095485         11    453095485-2-S11         NTP
# 47003  453095485         62    453095485-1-S62          EB
# 47004  453095485         63    453095485-1-S63          EB
# 47005  453095485         61    453095485-1-S61          EB
# 47007  453095485         64    453095485-1-S64          EB
# 47008  453095485         65    453095485-1-S65          EB
# 47010  453095485         67    453095485-1-S67          EB
# 47011  453095485         66    453095485-1-S66          EB
# 47012  453095485       1-13  453095485-1-S1-13          EB
# 47013  453095485       1-65  453095485-1-S1-65          EB
#         target_id sector_run            tce_uid disposition
# 94479   453211454         34    453211454-1-S34          CP
# 94480   453211454         34    453211454-2-S34          CP
# 94481   453211454          7     453211454-1-S7          CP
# 202196  453211454       1-36  453211454-1-S1-36          CP
# 202197  453211454       1-36  453211454-2-S1-36          CP
# 202198  453211454       1-36  453211454-3-S1-36         NTP
#         target_id sector_run            tce_uid disposition
# 120018  453828066         31    453828066-1-S31          EB
# 120020  453828066         31    453828066-3-S31         NTP
# 120021  453828066          4     453828066-1-S4          EB
# 120023  453828066          4     453828066-3-S4         NTP
# 200992  453828066       1-36  453828066-1-S1-36          EB
#         target_id sector_run            tce_uid disposition
# 115472  454190342         32    454190342-1-S32          EB
# 115473  454190342          5     454190342-1-S5          EB
# 201307  454190342       1-36  454190342-3-S1-36         NTP
#         target_id sector_run         tce_uid disposition
# 144464  455064763          5  455064763-1-S5          EB
# 144465  455064763          5  455064763-2-S5         NTP
# 144466  455064763          5  455064763-3-S5         NTP
#         target_id sector_run          tce_uid disposition
# 133125  455178154          7   455178154-1-S7         NTP
# 133126  455178154          7   455178154-2-S7         NTP
# 133128  455178154         61  455178154-2-S61          EB
#        target_id sector_run             tce_uid disposition
# 17544  455790537         16     455790537-1-S16         NTP
# 17545  455790537         17     455790537-1-S17          EB
# 17546  455790537         17     455790537-2-S17         NTP
# 17547  455790537      14-19  455790537-1-S14-19          EB
# 17548  455790537      14-19  455790537-2-S14-19         NTP
#        target_id sector_run             tce_uid disposition
# 17584  455824124         57     455824124-1-S57          EB
# 17590  455824124         18     455824124-1-S18          EB
# 17592  455824124         24     455824124-1-S24          EB
# 17594  455824124         16     455824124-1-S16          EB
# 17596  455824124         17     455824124-1-S17          EB
# 17597  455824124         17     455824124-2-S17         NTP
# 17598  455824124         58     455824124-1-S58          EB
# 17601  455824124      14-26  455824124-1-S14-26          EB
# 17602  455824124      14-26  455824124-2-S14-26         NTP
# 17603  455824124      14-26  455824124-3-S14-26         NTP
# 17604  455824124      14-19  455824124-1-S14-19          EB
# 17605  455824124      14-19  455824124-2-S14-19         NTP
# 17608  455824124      14-60  455824124-1-S14-60          EB
#        target_id sector_run             tce_uid disposition
# 87032  456263109         47     456263109-1-S47          EB
# 87035  456263109         20     456263109-1-S20          EB
# 87036  456263109         20     456263109-2-S20         NTP
# 87037  456263109         20     456263109-3-S20         NTP
# 87038  456263109         60     456263109-1-S60          EB
# 87040  456263109      14-50  456263109-1-S14-50          EB
#        target_id sector_run          tce_uid disposition
# 86884  457127187         47  457127187-1-S47          EB
# 86885  457127187         20  457127187-1-S20          EB
# 86886  457127187         20  457127187-2-S20         NTP
#        target_id sector_run             tce_uid disposition
# 68695  458481461         41     458481461-1-S41          EB
# 68699  458481461         23     458481461-1-S23         NTP
# 68700  458481461         23     458481461-2-S23         NTP
# 68702  458481461         24     458481461-1-S24         NTP
# 68703  458481461         24     458481461-2-S24         NTP
# 68704  458481461         15     458481461-1-S15          EB
# 68706  458481461         14     458481461-2-S14         NTP
# 68712  458481461      14-26  458481461-1-S14-26          EB
# 68716  458481461      14-23  458481461-1-S14-23          EB
# 68717  458481461      14-50  458481461-1-S14-50          EB
# 68718  458481461      14-41  458481461-1-S14-41          EB
#         target_id sector_run             tce_uid disposition
# 121095  458490358         25     458490358-2-S25          EB
# 121098  458490358      14-26  458490358-1-S14-26         NTP
# 121099  458490358      14-26  458490358-2-S14-26         NTP
# 121100  458490358      14-26  458490358-3-S14-26         NTP
#        target_id sector_run             tce_uid disposition
# 87311  459789367         21     459789367-1-S21          EB
# 87312  459789367         21     459789367-2-S21         NTP
# 87313  459789367         21     459789367-3-S21         NTP
# 87314  459789367      14-50  459789367-1-S14-50          EB
#        target_id sector_run             tce_uid disposition
# 59745  461579405         40     461579405-1-S40          EB
# 59746  461579405         52     461579405-1-S52          EB
# 59747  461579405         53     461579405-1-S53          EB
# 59749  461579405         20     461579405-1-S20          EB
# 59750  461579405         26     461579405-1-S26          EB
# 59751  461579405         25     461579405-1-S25         NTP
# 59752  461579405         25     461579405-2-S25          EB
# 59756  461579405      14-26  461579405-1-S14-26          EB
# 59758  461579405      14-23  461579405-1-S14-23          EB
# 59759  461579405      14-41  461579405-1-S14-41          EB
# 59761  461579405      14-55  461579405-1-S14-55          EB
# 59763  461579405      14-60  461579405-1-S14-60          EB
#         target_id sector_run            tce_uid disposition
# 104764  462267926          9     462267926-2-S9         NTP
# 104765  462267926         10    462267926-1-S10         NTP
# 104769  462267926         64    462267926-2-S64          EB
# 104770  462267926       1-13  462267926-1-S1-13         NTP
# 104771  462267926       1-13  462267926-2-S1-13         NTP
# 104772  462267926       1-65  462267926-1-S1-65          EB
#         target_id sector_run          tce_uid disposition
# 134913  464422047         13  464422047-1-S13          EB
# 134914  464422047         13  464422047-2-S13         NTP
# 134915  464422047         13  464422047-3-S13         NTP
# 134916  464422047         66  464422047-1-S66          EB
#         target_id sector_run            tce_uid disposition
# 109859  466323338         37    466323338-1-S37         NTP
# 109860  466323338         10    466323338-1-S10         NTP
# 109861  466323338         11    466323338-1-S11          EB
# 109864  466323338       1-13  466323338-1-S1-13          EB
# 109866  466323338       1-65  466323338-1-S1-65          EB
# 189007  466323338       1-39  466323338-1-S1-39          EB
#        target_id sector_run             tce_uid disposition
# 18295  467181063         54     467181063-1-S54          EB
# 18297  467181063         41     467181063-1-S41         NTP
# 18299  467181063         47     467181063-1-S47          EB
# 18301  467181063         53     467181063-1-S53          EB
# 18302  467181063         20     467181063-1-S20          EB
# 18303  467181063         21     467181063-1-S21          EB
# 18304  467181063         23     467181063-1-S23          EB
# 18306  467181063         22     467181063-1-S22          EB
# 18307  467181063         26     467181063-1-S26          EB
# 18308  467181063         19     467181063-1-S19         NTP
# 18309  467181063         18     467181063-1-S18         NTP
# 18311  467181063         17     467181063-1-S17          EB
# 18312  467181063         58     467181063-1-S58          EB
# 18314  467181063         59     467181063-1-S59          EB
# 18315  467181063      14-26  467181063-1-S14-26          EB
# 18317  467181063      14-19  467181063-1-S14-19          EB
# 18320  467181063      14-23  467181063-1-S14-23          EB
# 18322  467181063      14-50  467181063-1-S14-50          EB
# 18325  467181063      14-41  467181063-1-S14-41          EB
# 18327  467181063      14-55  467181063-1-S14-55          EB
# 18332  467181063      14-60  467181063-1-S14-60          EB
#        target_id sector_run             tce_uid disposition
# 85021  467354611         19     467354611-1-S19         NTP
# 85022  467354611         17     467354611-1-S17         NTP
# 85026  467354611      14-26  467354611-1-S14-26         NTP
# 85028  467354611      14-19  467354611-1-S14-19          EB
#        target_id sector_run             tce_uid disposition
# 85087  468293391         26     468293391-1-S26         NTP
# 85088  468293391         26     468293391-2-S26         NTP
# 85089  468293391         24     468293391-1-S24          EB
# 85091  468293391         24     468293391-3-S24         NTP
# 85093  468293391         58     468293391-2-S58          EB
# 85095  468293391         59     468293391-1-S59          EB
# 85097  468293391      14-26  468293391-2-S14-26         NTP
# 85098  468293391      14-26  468293391-3-S14-26          EB
# 85099  468293391      14-26  468293391-4-S14-26         NTP
# 85100  468293391      14-19  468293391-1-S14-19         NTP
# 85101  468293391      14-19  468293391-2-S14-19         NTP
# 85109  468293391      14-60  468293391-3-S14-60          EB
#        target_id sector_run             tce_uid disposition
# 85133  468343249         25     468343249-1-S25         NTP
# 85134  468343249         19     468343249-1-S19         NTP
# 85137  468343249         24     468343249-1-S24          EB
# 85139  468343249         59     468343249-1-S59          EB
# 85140  468343249      14-26  468343249-1-S14-26         NTP
# 85141  468343249      14-19  468343249-1-S14-19         NTP
# 85149  468343249      14-60  468343249-1-S14-60          EB
#        target_id sector_run          tce_uid disposition
# 31663  468792279         16  468792279-1-S16          EB
# 31664  468792279         16  468792279-2-S16         NTP
#         target_id sector_run          tce_uid disposition
# 134532  469441650         13  469441650-1-S13          EB
# 134534  469441650         13  469441650-3-S13         NTP
# 134535  469441650         13  469441650-4-S13         NTP
# 134536  469441650         66  469441650-1-S66          EB
#        target_id sector_run             tce_uid disposition
# 85182  470124714         52     470124714-1-S52          EB
# 85184  470124714         53     470124714-1-S53          EB
# 85186  470124714         26     470124714-1-S26          EB
# 85188  470124714         25     470124714-1-S25         NTP
# 85189  470124714         19     470124714-1-S19          EB
# 85192  470124714         18     470124714-2-S18         NTP
# 85195  470124714         60     470124714-2-S60          EB
# 85196  470124714         58     470124714-1-S58          EB
# 85198  470124714         59     470124714-1-S59          EB
# 85200  470124714      14-26  470124714-1-S14-26          EB
# 85204  470124714      14-55  470124714-1-S14-55          EB
# 85206  470124714      14-60  470124714-1-S14-60          EB
#        target_id sector_run             tce_uid disposition
# 88763  470152814         19     470152814-1-S19         NTP
# 88765  470152814         24     470152814-1-S24         NTP
# 88767  470152814      14-26  470152814-1-S14-26          EB
# 88769  470152814      14-19  470152814-1-S14-19          EB
# 88771  470152814      14-55  470152814-1-S14-55          EB
# 88773  470152814      14-60  470152814-1-S14-60          EB
#        target_id sector_run             tce_uid disposition
# 18244  470710327         58     470710327-2-S58          EB
# 18245  470710327      14-26  470710327-1-S14-26         NTP
# 18248  470710327      14-26  470710327-4-S14-26         NTP
# 18249  470710327      14-26  470710327-5-S14-26         NTP
# 18251  470710327      14-19  470710327-2-S14-19         NTP
#          target_id sector_run              tce_uid disposition
# 107398  1883519478         23     1883519478-1-S23          EB
# 107399  1883519478         15     1883519478-1-S15          EB
# 107400  1883519478         15     1883519478-2-S15         NTP
# 107401  1883519478         14     1883519478-1-S14          EB
# 107402  1883519478         14     1883519478-2-S14         NTP
# 107403  1883519478         16     1883519478-1-S16          EB
# 107408  1883519478      14-19  1883519478-1-S14-19          EB
# 107413  1883519478      14-23  1883519478-1-S14-23          EB
# 107414  1883519478      14-23  1883519478-2-S14-23          EB
#          target_id sector_run              tce_uid disposition
# 124974  1981434198         24     1981434198-1-S24         NTP
# 124975  1981434198         16     1981434198-1-S16         NTP
# 124976  1981434198         17     1981434198-1-S17         NTP
# 124977  1981434198      14-26  1981434198-1-S14-26         NTP
# 124978  1981434198      14-19  1981434198-1-S14-19         NTP
# 124979  1981434198      14-19  1981434198-2-S14-19         NTP
# 124981  1981434198      14-60  1981434198-1-S14-60          EB

# %%
for disps, targets  in mixed_targets_by_disp.items():
    if 161563111 in targets:
        print(F"FOUND: {disps, targets}")
# Out:
# FOUND: (('NTP', 'NTP', 'EB', 'EB', 'EB'), [41591173, 161563111, 362791996, 452631268])

# %%
print(f"Total number of unique targets: {len(tce_tbl["target_id"].unique())}")
print(f"number of unique targets with at least one...")
for disp in ["EB", "CP", "KP", "NTP", "NPC", "NEB"]:
    print(f"\t {disp} TCE example: {len(tce_tbl[tce_tbl['disposition'] == disp]['target_id'].unique())} ")
# Out:
#   Cell In[37], line 1
#     print(f"Total number of unique targets: {len(tce_tbl["target_id"].unique())}")
#                                                           ^
# SyntaxError: f-string: unmatched '['

# %%
cps = []
non_cps = []
i = 0
for disps, targets  in mixed_targets_by_disp.items():
    if "CP" in disps:
        i += 1
        cps.extend(targets)
        print(disps, targets)
    else:
        non_cps.extend(targets)
# Out:
# ('NTP', 'CP') [27491137, 206541859, 349576261]
# ('NTP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP') [29781292]
# ('NTP', 'NTP', 'NTP', 'NTP', 'NTP', 'NTP', 'NTP', 'CP', 'NTP', 'NTP', 'NTP', 'NTP', 'NTP', 'NTP', 'CP', 'NTP', 'NTP', 'NTP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP') [55652896]
# ('CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'NTP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP') [142276270]
# ('NTP', 'CP', 'NTP', 'NTP') [149601126]
# ('CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'NTP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP') [150098860]
# ('CP', 'NTP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP') [150151262]
# ('CP', 'CP', 'CP', 'CP', 'NTP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP') [150428135]
# ('NTP', 'CP', 'CP') [179034327]
# ('CP', 'NTP', 'CP', 'CP') [199376584, 408636441]
# ('CP', 'CP', 'CP', 'NTP', 'CP', 'NTP', 'CP', 'NTP', 'CP', 'NTP', 'NTP', 'NTP', 'NTP') [200322593]
# ('CP', 'NTP', 'NTP', 'CP') [200723869]
# ('NTP', 'NTP', 'NTP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP') [229742722]
# ('NTP', 'NTP', 'CP', 'CP', 'CP', 'CP') [257605131]
# ('CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'NTP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'NTP', 'CP', 'CP', 'CP', 'CP', 'CP') [261136679]
# ('CP', 'CP', 'NTP', 'CP', 'CP', 'NTP', 'CP', 'CP', 'CP', 'CP', 'CP') [267574918]
# ('CP', 'NTP', 'CP', 'NTP', 'CP', 'CP', 'CP', 'CP', 'CP') [279741379]
# ('NTP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'NTP') [280206394]
# ('NTP', 'NTP', 'NTP', 'EB', 'CP', 'EB', 'EB') [309792357]
# ('CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'NTP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP') [339672028]
# ('NTP', 'NTP', 'NTP', 'NTP', 'NTP', 'NTP', 'NTP', 'NTP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP') [350618622]
# ('CP', 'CP', 'NTP', 'CP') [351601843]
# ('CP', 'NTP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP') [358107516]
# ('CP', 'CP', 'CP', 'NTP', 'CP', 'CP', 'CP', 'CP', 'NTP') [366622912]
# ('CP', 'NTP', 'NTP', 'CP', 'NTP', 'NTP', 'CP', 'NTP', 'NTP') [410214986]
# ('CP', 'NEB', 'CP', 'NEB', 'CP', 'CP', 'CP') [441738827]
# ('NTP', 'NTP', 'NTP', 'NTP', 'CP', 'CP', 'NTP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP', 'CP') [441739020]
# ('NTP', 'NTP', 'NTP', 'NTP', 'CP', 'CP', 'CP', 'CP', 'CP') [445805961]
# ('NTP', 'NTP', 'NTP', 'CP', 'NTP', 'CP') [447061717]
# ('CP', 'CP', 'CP', 'CP', 'CP', 'NTP') [453211454]
# 30

# %%
# Out:
# 33 1256

# %%
interest_cols = ["target_id", "tce_uid", "disposition", "tce_time0bk", "tce_period", "tce_duration", "tce_maxmes", "tce_maxmesd"]

# %%
# tce_tbl[tce_tbl["target_id"] == 150098860][interest_cols] 
# 159444225
# 159298033
unfil_tce_tbl[unfil_tce_tbl["target_id"] == 408636441][interest_cols]
#

# unfil_tce_tbl[unfil_tce_tbl["tce_uid"] == "159298033-1-S25"][interest_cols]
# unfil_tce_tbl[unfil_tce_tbl["tce_uid"] == "161563111-1-S14-41"][interest_cols]
# Out:
#        target_id             tce_uid disposition  tce_time0bk  tce_period  \
# 15825  408636441     408636441-1-S57          CP  2857.615393   18.854255
# 15826  408636441     408636441-1-S24         NTP  1959.461751   12.207094
# 15827  408636441     408636441-1-S16         UNK  1745.616690   16.190585
# 15828  408636441  408636441-1-S14-26         UNK  1745.465768   37.700297
# 15829  408636441  408636441-1-S14-19          CP  1745.466772   37.697104
# 15830  408636441  408636441-1-S14-60          CP  1745.465476   18.850002
#
#        tce_duration  tce_maxmes  tce_maxmesd
# 15825      3.583558    2.526857    -1.218055
# 15826      3.366489    3.428051     3.176388
# 15827     14.416994    2.341625    10.834717
# 15828      3.493242    3.037859    -9.055552
# 15829      3.528458    2.311211     1.252777
# 15830      3.561106    2.970302     4.968751

# %% [markdown]
# ### Investigating Neg Dispositions (NTP, NEB, NPC) overlap w/ Pos Dispositions (EB, KP, CP) at the target, sector_run level

# %%
t_sr_groups = tce_tbl.groupby(["target_id", "sector_run"])

# %% [markdown]
# Filter for target, sector_runs that have both Pos and Neg disposition TCEs

# %%
mixed_t_sr_groups = t_sr_groups.filter(
    lambda g: 
        (np.isin(np.array(["EB", "CP", "KP"]), g["disposition"].unique()).any())
        and 
        (np.isin(np.array(["NTP", "NEB", "NPC"]), g["disposition"].unique()).any())
).groupby(["target_id", "sector_run"])

# %%
# Out:
# 1289

# %% [markdown]
# ### Specific (target, sector_run) pairs

# %%
target, sector_run = 198242678, "14-19" # 30034081, "7"

# %%
sector_run_arr = []

if "-" in sector_run:
    start_sector, end_sector = [
        int(sector) for sector in sector_run.split("-")
    ]
    sector_run_arr = [
        sector for sector in range(start_sector, end_sector + 1)
    ]
else:
    sector_run_arr = [int(sector_run)]

# find light curve data for target, sector_run pair
search_lc_res = lk.search_lightcurve(
    target=f"tic{target}",
    mission="TESS",
    author=("TESS-SPOC", "SPOC"),
    exptime=120,
    cadence="long",
    sector=sector_run_arr,
)

# %%
lcfs_def = search_lc_res.download_all(
    quality_bitmask="default", flux_column="pdcsap_flux"
)

lcfs_none = search_lc_res.download_all(
    quality_bitmask="none", flux_column="pdcsap_flux"
)

found_sectors = [int(el.split(' ')[-1]) for el in search_lc_res.table["mission"]]

# %%
found_sectors
# Out:
# [14, 16, 17, 18, 19]

# %%
lcf_def = lcfs_def[0]

lcf_def = lk.LightCurve({"time": np.array(lcf_def.time.value), "flux": np.array(lcf_def.flux.value)})

lcf_none = lcfs_none[0]

lcf_none = lk.LightCurve({"time": np.array(lcf_none.time.value), "flux": np.array(lcf_none.flux.value)})

print(f"default mask max_diff: {np.max(np.diff(lcf_def.time.value))}")
print(f"no mask max_diff: {np.max(np.diff(lcf_none.time.value))}")
print(len(lcf_def.time.value))
print(len(lcf_none.time.value))
# Out:
# default mask max_diff: 0.9555375604454639
# no mask max_diff: 0.9499821161348336
# 18424
# 18654

# %%
lcf_fits_fp = "/Users/jochoa4/Downloads/MAST_2025-06-09T2246/TESS/tess2019279210107-s0017-0000000198242678-0161-s/tess2019279210107-s0017-0000000198242678-0161-s_lc.fits"

# %%
import astropy.io.fits as fits
lcf = fits.open(lcf_fits_fp)

# %%
lcf_def

# %%
lcf.info()
# Out:
# Filename: /Users/jochoa4/Downloads/MAST_2025-06-09T2246/TESS/tess2019279210107-s0017-0000000198242678-0161-s/tess2019279210107-s0017-0000000198242678-0161-s_lc.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      44   ()
#   1  LIGHTCURVE    1 BinTableHDU    167   18012R x 20C   [D, E, J, E, E, E, E, E, E, J, D, E, D, E, D, E, D, E, E, E]
#   2  APERTURE      1 ImageHDU        49   (11, 13)   int32

# %%
from astropy.table import Table
table = Table.read(lcf_fits_fp)
# Out:
# WARNING: UnitsWarning: 'BJD - 2457000, days' did not parse as fits unit: At col 0, Unit 'BJD' not supported by the FITS standard.  If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'e-/s' did not parse as fits unit: At col 0, Unit 'e' not supported by the FITS standard.  If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'pixels' did not parse as fits unit: At col 0, Unit 'pixels' not supported by the FITS standard. Did you mean pixel? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]

# %%
type(table["TIME"])
# Out:
# astropy.table.column.MaskedColumn

# %%
raw_time, np_time = table["TIME"], np.array(table["TIME"])
len(raw_time) == len(np_time)
# Out:
# True

# %%
np.max(np.ma.diff(raw_time)), np.max(np.diff(np_time[np.where(np.isfinite(np_time))[0]))

# %%
len(np.ma.diff(raw_time))
# Out:
# 18011

# %%
len(np.diff(np_time))
# Out:
# 18011

# %%
raw_time[0], raw_time[-1]
# Out:
# (1764.6778258441836, 1789.6931248626518)

# %%
exp_num_idxs = len(np.arange(raw_time[0], raw_time[-1], 2 / 1440))
exp_num_idxs
# Out:
# 18012

# %%
len(raw_time[np.isfinite(raw_time)])
# Out:
# 16982

# %%
# Out:
# (0.001388899230505558, 0.001388881300954381)

# %%
len(table["TIME"]) == len(np.array(table["TIME"]))
# Out:
# True

# %%
time = np.array(table["TIME"])

# %%
time_diff = np.diff(np.array(table["TIME"]))

# %%
nan_time_idxs = np.where((~np.isfinite(time)))[0]
nan_time_idxs
# Out:
# array([ 8364,  8365,  8366, ...,  9391, 17645, 17646])

# %%
time_nan =

# %%
len(nan_time_idxs)
# Out:
# 1030

# %%
nan_time_idxs =

# %%
nan_time_idxs = np.where(((np.isnan(np.array(table["TIME"]))) == (~np.isfinite(np.array(table["TIME"])))).all())

# %%
# Out:
# (array([0]),)

# %%
np.isfinite(np.array(table["TIME"]))
# Out:
# array([ True,  True,  True, ...,  True,  True,  True])

# %%
lcf_def = lcfs_def[2]
lcf_def
# Out:
# <TessLightCurve length=16663 LABEL="TIC 198242678" SECTOR=17 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#        time             flux      ...   pos_corr1      pos_corr2
#                     electron / s  ...      pix            pix
#        Time           float32     ...    float32        float32
# ------------------ -------------- ... -------------- --------------
# 1764.6833813693875  1.0791109e+05 ...  1.1205494e-02  5.1924460e-02
# 1764.6847702506886  1.0790324e+05 ...  1.0921710e-02  4.9388994e-02
# 1764.6861591319896  1.0785036e+05 ...  5.0868765e-03  4.9628641e-02
# 1764.6875480132912  1.0793118e+05 ...  1.5811194e-02  5.5337731e-02
#  1764.688936894593  1.0788295e+05 ...  9.3892375e-03  5.0588921e-02
#  1764.690325775894  1.0785216e+05 ...  8.7993387e-03  4.9752053e-02
#  1764.691714657195  1.0796320e+05 ...  9.4211334e-03  4.9416382e-02
# 1764.6931035384962  1.0797679e+05 ...  1.3968344e-02  5.1046737e-02
# 1764.6944924196807  1.0790055e+05 ...  1.1146292e-02  5.5413593e-02
#                ...            ... ...            ...            ...
#  1789.680624783673            ——— ...  7.2077168e-03 -2.8450571e-02
# 1789.6820136813894            ——— ...  1.6151166e-02 -3.9205477e-02
# 1789.6834025791063            ——— ...  1.0099521e-02 -3.2014526e-02
# 1789.6847914768225            ——— ...  4.0503149e-03 -3.0382965e-02
# 1789.6861803744218            ——— ...  1.1089616e-02 -3.3875246e-02
# 1789.6875692721374            ——— ...  1.2853898e-02 -3.4386195e-02
# 1789.6889581697365            ——— ...  5.6519425e-03 -3.0596966e-02
# 1789.6903470674529            ——— ...  9.7263968e-03 -3.1945106e-02
# 1789.6917359650527            ——— ...  1.0358983e-02 -3.5885680e-02
# 1789.6931248626518            ——— ...  9.1585042e-03 -3.4346003e-02

# %%
len(lcf_def.time.value) == len(np.array(lcf_def.time.value))
# Out:
# True

# %%
lcf_def.time
# Out:
# <Time object: scale='tdb' format='btjd' value=[1764.68338137 1764.68477025 1764.68615913 ... 1789.69034707 1789.69173597
#  1789.69312486]>

# %%
type(lcf_def.time.value)
# Out:
# numpy.ndarray

# %%
lcfs_def[2]
# Out:
# <TessLightCurve length=16663 LABEL="TIC 198242678" SECTOR=17 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#        time             flux      ...   pos_corr1      pos_corr2
#                     electron / s  ...      pix            pix
#        Time           float32     ...    float32        float32
# ------------------ -------------- ... -------------- --------------
# 1764.6833813693875  1.0791109e+05 ...  1.1205494e-02  5.1924460e-02
# 1764.6847702506886  1.0790324e+05 ...  1.0921710e-02  4.9388994e-02
# 1764.6861591319896  1.0785036e+05 ...  5.0868765e-03  4.9628641e-02
# 1764.6875480132912  1.0793118e+05 ...  1.5811194e-02  5.5337731e-02
#  1764.688936894593  1.0788295e+05 ...  9.3892375e-03  5.0588921e-02
#  1764.690325775894  1.0785216e+05 ...  8.7993387e-03  4.9752053e-02
#  1764.691714657195  1.0796320e+05 ...  9.4211334e-03  4.9416382e-02
# 1764.6931035384962  1.0797679e+05 ...  1.3968344e-02  5.1046737e-02
# 1764.6944924196807  1.0790055e+05 ...  1.1146292e-02  5.5413593e-02
#                ...            ... ...            ...            ...
#  1789.680624783673            ——— ...  7.2077168e-03 -2.8450571e-02
# 1789.6820136813894            ——— ...  1.6151166e-02 -3.9205477e-02
# 1789.6834025791063            ——— ...  1.0099521e-02 -3.2014526e-02
# 1789.6847914768225            ——— ...  4.0503149e-03 -3.0382965e-02
# 1789.6861803744218            ——— ...  1.1089616e-02 -3.3875246e-02
# 1789.6875692721374            ——— ...  1.2853898e-02 -3.4386195e-02
# 1789.6889581697365            ——— ...  5.6519425e-03 -3.0596966e-02
# 1789.6903470674529            ——— ...  9.7263968e-03 -3.1945106e-02
# 1789.6917359650527            ——— ...  1.0358983e-02 -3.5885680e-02
# 1789.6931248626518            ——— ...  9.1585042e-03 -3.4346003e-02

# %%
cadenceno_none = lcfs_none[2].cadenceno

# %%
cadenceno_none
# Out:
# <Column name='cadenceno' dtype='int32' format='{:10d}' length=16982>
#     386801
#     386802
#     386803
#     386804
#     386805
#     386806
#     386807
#     386808
#     386809
#     386810
#     386811
#     386812
#        ...
#     404801
#     404802
#     404803
#     404804
#     404805
#     404806
#     404807
#     404808
#     404809
#     404810
#     404811
#     404812

# %%
time_skips = np.where(np.diff(lcfs_none[2].time.value) > (10 * 2 / 1440))[0]


for skip in time_skips:
    print(lcfs_none[2][skip - 5: skip + 5].time, lcfs_none[2][skip - 5: skip + 5].cadenceno)
# Out:
# [1776.2861436  1776.2875325  1776.28892139 1776.29031028 1776.29169918
#  1776.29308807 1777.72225593 1777.72364481 1777.7250337  1777.72642259] cadenceno
# ----------
#     395159
#     395160
#     395161
#     395162
#     395163
#     395164
#     396193
#     396194
#     396195
#     396196

# %%
len(lcfs_def[2].time.value)
# Out:
# 16663

# %%
lcfs_none = search_lc_res.download_all(
    quality_bitmask="none", flux_column="pdcsap_flux"
)
lcfs_zero = search_lc_res.download_all(
    quality_bitmask=0, flux_column="pdcsap_flux"
)

# %%
print(len(lcfs_zero[0].time.value))
print(len(lcfs_none[0].time.value))
np.max(np.diff(lcfs_zero[0].time.value))
# Out:
# 18654
# 18654
# 0.9499821161348336

# %% [markdown]
# ## Testing interpolation/extrapolation

# %%
lcf_lk = lk.read(lcf_fits_fp)

lcf_lk.plot()

time_lk = lcf_lk.time.value
flux_lk = lcf_lk.flux.value

# %%
def fill_missing_tess_cadences(
    time: np.ndarray, strategy: str = ""
):

    if not isinstance(time, np.ndarray):
        print(f"time: {type(time)}")
        time = np.array(time)

    missing_cadence_mask = ~np.isfinite(time)

    n_cadences = len(time)
    valid_idxs = np.where(np.isfinite(time))[0]  # returns actual idxs, not mask

    if n_cadences == len(valid_idxs):
        return time, np.zeros_like(time).astype(bool)  # time has no missing values

    if strategy == "average":
        cadence = np.nanmean(np.diff(time[valid_idxs]))
    elif strategy == "median":
        cadence = np.nanmedian(np.diff(time[valid_idxs]))
    else:
        cadence = 2 / 1440  # 2mins in days for TESS

    # if first/last idx are valid, use directly else offset by cadnece * idx dist to start/end
    t_start = time[valid_idxs][0] - valid_idxs[0] * cadence
    t_end = time[valid_idxs][-1] + ((n_cadences - 1) - valid_idxs[-1]) * cadence

    time_filled = np.linspace(t_start, t_end, n_cadences)

    return time_filled, missing_cadence_mask

# %%
def fill_missing_flux(time, flux, cadence_mask):

    f = interp1d(
        time[(~cadence_mask)],
        flux[(~cadence_mask)],
        kind="linear",
        bounds_error=False,
        fill_value="extrapolate",  # assume_sorted=True
    )

    filled_flux = f(time)

    return filled_flux

# %%
def detrend_flux_using_sg_filter(lc, mask_in_transit, win_len, sigma, max_poly_order, penalty_weight, break_tolerance):
    """ Detrend timeseries by applying a Savitzky-Golay filter to a version of the timeseries where in-transit cadences
    are masked (i.e., not taken into account).

    Args:
        lc: lightcurve object, with raw timestamps and timeseries
        mask_in_transit: NumPy array, in-transit cadences are flagged as True
        win_len: int, number of points considered in the window
        sigma: outlier factor used to mask data points before detrending (i.e., x - med(flux) >= sigma * std(flux))
        max_poly_order: int, maximum polynomial order tested
        penalty_weight: float: weight given to model's complexity when using BIC for model selection
        break_tolerance: float, factor used to split the timeseries into smaller segments based on time interval between
            cadences (i.e., there's a split if diff(t_x) > break_tolerance * med(diff(T)))

    Returns:
        - time, NumPy array with timestamps
        - detrended_flux, NumPy array with detrended timeseries (i.e., detrended_flux = flux / trend)
        - trend, NumPy array with trend
        - models_info_df, pandas DataFrame with BIC scores for the fitted models
    """

    if mask_in_transit.all():
        time = lc.time.value
        trend = np.nanmedian(lc.flux.value) * np.ones_like(lc.flux.value)
        detrended_flux = lc.flux.value / trend
        trend = np.ones_like(lc.flux.value)
        models_info_df = pd.DataFrame({'poly_order': [0], 'bic_score': [np.nan]})

        return time, detrended_flux, trend, models_info_df

    n_samples = len(lc.flux.value)
    poly_order_arr = np.arange(0, max_poly_order + 1)
    best_bic, best_model = np.inf, 0
    lc_detrended = {poly_order: {'flux': None, 'trend': None, 'bic': np.nan} for poly_order in poly_order_arr}
    for poly_order in poly_order_arr:

        lc_sector_flatten, lc_sector_trend = lc.flatten(window_length=win_len, polyorder=poly_order, return_trend=True,
                                                        sigma=sigma, mask=mask_in_transit,
                                                        break_tolerance=break_tolerance)
        lc_detrended[poly_order]['flux'] = lc_sector_flatten.copy()
        lc_detrended[poly_order]['trend'] = lc_sector_trend.copy()

        bic_k = compute_bic(poly_order, n_samples, lc.flux.value, lc_sector_trend.flux.value,
                            penalty_weight=penalty_weight)
        lc_detrended[poly_order]['bic'] = bic_k
        if bic_k < best_bic:
            best_bic, best_model = bic_k, poly_order

    bic_scores = [lc_detrended[poly_order]['bic'] for poly_order in lc_detrended]
    models_info_df = pd.DataFrame({'poly_order': poly_order_arr, 'bic_score': bic_scores})
    models_info_df.sort_values(by='bic_score', ascending=True, inplace=True)
    models_info_df.set_index('poly_order', inplace=True)

    time, detrended_flux = lc_detrended[best_model]['flux'].time.value, lc_detrended[best_model]['flux'].flux.value
    trend = lc_detrended[best_model]['trend'].flux.value

    # remove median from trend (by time splits)
    dt = np.diff(time)
    cut = np.where(dt > break_tolerance * np.nanmedian(dt))[0] + 1
    low = np.append([0], cut)
    high = np.append(cut, len(time))
    for low_i, high_i in zip(low, high):
        trend[low_i: high_i] /= np.nanmedian(trend[low_i: high_i])

    return time, detrended_flux, trend, models_info_df

# %%
lcf_ap_table = Table.read(lcf_fits_fp, format="fits")

quality_ap = lcf_ap_table["QUALITY"].value
default_bitmask = 17087

time_ap_unproc = lcf_ap_table["TIME"].value.filled(np.nan)
flux_ap_unproc = lcf_ap_table["PDCSAP_FLUX"].value.filled(np.nan)

# lcf_ap_unproc = lk.LightCurve({"time": time_ap_unproc, "flux": flux_ap_unproc})
# lcf_ap_unproc.plot()
# time_ap_unproc = np.array(time_ap_unproc)
# flux_ap_unproc = np.array(flux_ap_unproc)

time_ap_proc, cadence_mask = fill_missing_tess_cadences(time_ap_unproc)
print(f"max diff mins: {np.max(np.diff(time_ap_proc) * 1440)}")
lcf_ap_time_proc = lk.LightCurve({"time": time_ap_proc, "flux": flux_ap_unproc})
lcf_ap_time_proc.plot()

valid_quality_idxs_ap = (default_bitmask & quality_ap) == 0
valid_flux_idxs_ap = np.isfinite(flux_ap_unproc)

cadence_mask |= ~valid_quality_idxs_ap
cadence_mask |= ~valid_flux_idxs_ap

flux_ap_proc = flux_ap_unproc.copy()
flux_ap_proc[cadence_mask] = np.nan

lcf_ap_proc = lk.LightCurve({"time": time_ap_proc, "flux": flux_ap_proc})
lcf_ap_proc.plot()
print(np.isfinite(lcf_ap_proc.time.value).sum())
print(len(lcf_ap_proc.time.value))

print(np.isfinite(lcf_ap_proc.flux.value).sum())
print(len(lcf_ap_proc.flux.value))

interp_flux = fill_missing_flux(time_ap_proc, flux_ap_proc, cadence_mask)
print(type(interp_flux))
lcf_ap_interp = lk.LightCurve({"time": time_ap_proc, "flux": interp_flux})

lcf_ap_interp.plot()
lcf_ap_interp.plot()

# plt.scatter(time_ap_proc, interp_flux)
# lk.LightCurve({"time": time_ap_proc[~cadence_mask], "flux": interp_flux[~cadence_mask]}).plot()
plt.fill_between(time_ap_proc, np.min(interp_flux), np.max(interp_flux), where=cadence_mask)
plt.show()
#detrend
# Out:
# max diff mins: 2.0000016982885427
# 18012
# 18012
# 12620
# 18012
# <class 'numpy.ndarray'>
# WARNING: UnitsWarning: 'BJD - 2457000, days' did not parse as fits unit: At col 0, Unit 'BJD' not supported by the FITS standard.  If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'e-/s' did not parse as fits unit: At col 0, Unit 'e' not supported by the FITS standard.  If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'pixels' did not parse as fits unit: At col 0, Unit 'pixels' not supported by the FITS standard. Did you mean pixel? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]

# %%
detrend_time, detrend_flux, detrend_trend, _ = detrend_flux_using_sg_filter()
